# %%
# %matplotlib inline
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader,Dataset
import matplotlib.pyplot as plt
import torchvision.utils
import numpy as np
import random
from PIL import Image
import torch
from torch.autograd import Variable
import PIL.ImageOps    
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from PIL import Image
import os

# %%
# 준비된 이미지 데이터가 없을 때 사용
# !git clone https://github.com/alpha-13/Face-Recognition.git

# %%
def imshow(img,text=None,should_save=False):
    npimg = img.numpy()
    plt.axis("off")
    if text:
        plt.text(75, 8, text, style='italic',fontweight='bold',
            bbox={'facecolor':'white', 'alpha':0.8, 'pad':10})
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

def show_plot(iteration,loss):
    plt.plot(iteration,loss)
    plt.show()

# %%
# !mkdir /content/images1
# !unzip /content/imgs1 -d /content/images1
# Out:
# Archive:  /content/imgs1.zip
#    creating: /content/images1/Testing/
#    creating: /content/images1/Testing/s1/
#   inflating: /content/images1/Testing/s1/1.jpg
#    creating: /content/images1/Testing/s10/
#   inflating: /content/images1/Testing/s10/10.jpg
#    creating: /content/images1/Testing/s11/
#   inflating: /content/images1/Testing/s11/11.jpg
#    creating: /content/images1/Testing/s12/
#   inflating: /content/images1/Testing/s12/12.jpg
#    creating: /content/images1/Testing/s13/
#   inflating: /content/images1/Testing/s13/13.jpg
#    creating: /content/images1/Testing/s14/
#   inflating: /content/images1/Testing/s14/14.jpg
#    creating: /content/images1/Testing/s15/
#   inflating: /content/images1/Testing/s15/15.jpg
#    creating: /content/images1/Testing/s16/
#   inflating: /content/images1/Testing/s16/16.jpg
#    creating: /content/images1/Testing/s17/
#   inflating: /content/images1/Testing/s17/17.jpg
#    creating: /content/images1/Testing/s18/
#   inflating: /content/images1/Testing/s18/18.jpg
#    creating: /content/images1/Testing/s19/
#   inflating: /content/images1/Testing/s19/19.jpg
#    creating: /content/images1/Testing/s2/
#   inflating: /content/images1/Testing/s2/2.jpg
#    creating: /content/images1/Testing/s3/
#   inflating: /content/images1/Testing/s3/3.jpg
#    creating: /content/images1/Testing/s4/
#   inflating: /content/images1/Testing/s4/4.jpg
#    creating: /content/images1/Testing/s5/
#   inflating: /content/images1/Testing/s5/5.jpg
#    creating: /content/images1/Testing/s6/
#   inflating: /content/images1/Testing/s6/6.jpg
#    creating: /content/images1/Testing/s7/
#   inflating: /content/images1/Testing/s7/7.jpg
#    creating: /content/images1/Testing/s8/
#   inflating: /content/images1/Testing/s8/8.jpg
#    creating: /content/images1/Testing/s9/
#   inflating: /content/images1/Testing/s9/9.jpg
#    creating: /content/images1/Training/
#    creating: /content/images1/Training/s1/
#   inflating: /content/images1/Training/s1/1.jpg
#    creating: /content/images1/Training/s10/
#   inflating: /content/images1/Training/s10/다운로드 (20).jpg
#    creating: /content/images1/Training/s11/
#   inflating: /content/images1/Training/s11/다운로드 (22).jpg
#    creating: /content/images1/Training/s12/
#   inflating: /content/images1/Training/s12/다운로드 (24).jpg
#    creating: /content/images1/Training/s13/
#   inflating: /content/images1/Training/s13/다운로드 (26).jpg
#    creating: /content/images1/Training/s14/
#   inflating: /content/images1/Training/s14/다운로드 (28).jpg
#    creating: /content/images1/Training/s15/
#   inflating: /content/images1/Training/s15/다운로드 (32).jpg
#    creating: /content/images1/Training/s16/
#   inflating: /content/images1/Training/s16/다운로드 (34).jpg
#    creating: /content/images1/Training/s17/
#   inflating: /content/images1/Training/s17/다운로드 (36).jpg
#    creating: /content/images1/Training/s18/
#   inflating: /content/images1/Training/s18/18.jpg
#    creating: /content/images1/Training/s19/
#   inflating: /content/images1/Training/s19/19.jpg
#    creating: /content/images1/Training/s2/
#   inflating: /content/images1/Training/s2/다운로드 (4).jpg
#    creating: /content/images1/Training/s3/
#   inflating: /content/images1/Training/s3/다운로드 (6).jpg
#    creating: /content/images1/Training/s4/
#   inflating: /content/images1/Training/s4/다운로드 (8).jpg
#    creating: /content/images1/Training/s5/
#   inflating: /content/images1/Training/s5/다운로드 (10).jpg
#    creating: /content/images1/Training/s6/
#   inflating: /content/images1/Training/s6/다운로드 (12).jpg
#    creating: /content/images1/Training/s7/
#   inflating: /content/images1/Training/s7/다운로드 (14).jpg
#    creating: /content/images1/Training/s8/
#   inflating: /content/images1/Training/s8/다운로드 (16).jpg
#    creating: /content/images1/Training/s9/
#   inflating: /content/images1/Training/s9/다운로드 (18).jpg

# %%
class Config():
    training_dir = "/content/images1/Training"
    testing_dir = "/content/images1/Testing"
    train_batch_size = 8
    train_number_epochs = 100

# %%
class SiameseNetworkDataset(Dataset):
    
    def __init__(self, imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        
    def __getitem__(self,index):
        img0_tuple = random.choice(self.imageFolderDataset.imgs)
        #we need to make sure approx 50% of images are in the same class
        should_get_same_class = random.randint(0,1) 
        if should_get_same_class:
            while True:
                #keep looping till the same class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs)
                if img0_tuple[1]==img1_tuple[1]:
                    break
        else:
            while True:
                #keep looping till a different class image is found
                img1_tuple = random.choice(self.imageFolderDataset.imgs)
                if img0_tuple[1] !=img1_tuple[1]:
                    break

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %%
folder_dataset = dset.ImageFolder(root=Config.training_dir)
siamese_dataset = SiameseNetworkDataset(imageFolderDataset=folder_dataset,
                                        transform=transforms.Compose([transforms.Resize((100,100)),
                                                                      transforms.ToTensor()
                                                                      ])
                                       ,should_invert=False)

# %%
vis_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=8)
dataiter = iter(vis_dataloader)

example_batch = next(dataiter)
'''
 torch.cat()은 주어진 차원을 기준으로 주어진 텐서들을 붙임(concatenate)
 따라서, (3, 4)의 크기(shape)를 갖는 2개의 텐서 A와 B를 붙이는 경우,
 torch.cat([A, B], dim=0)의 결과는 (6, 4)의 크기(shape)를 갖음
'''
concatenated = torch.cat((example_batch[0],example_batch[1]),0)
imshow(torchvision.utils.make_grid(concatenated))
print(example_batch[2].numpy())
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [0.]
#  [1.]
#  [0.]]

# %%
class SiameseNetwork(nn.Module):
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.cnn1 = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(1, 4, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(4),
            
            nn.ReflectionPad2d(1),
            nn.Conv2d(4, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),

            nn.ReflectionPad2d(1),
            nn.Conv2d(8, 8, kernel_size=3),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(8),
        )

        self.fc1 = nn.Sequential(
            nn.Linear(8*100*100, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 500),
            nn.ReLU(inplace=True),

            nn.Linear(500, 5))

    def forward_once(self, x):
        output = self.cnn1(x)
        output = output.view(output.size()[0], -1)
        output = self.fc1(output)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %%
class ContrastiveLoss(torch.nn.Module):
    """
    Contrastive loss function.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    """

    def __init__(self, margin=2.0):
        super(ContrastiveLoss, self).__init__()
        self.margin = margin

    def forward(self, output1, output2, label):
        euclidean_distance = F.pairwise_distance(output1, output2, keepdim = True)
        loss_contrastive = torch.mean((1-label) * torch.pow(euclidean_distance, 2) +
                                      (label) * torch.pow(torch.clamp(self.margin - euclidean_distance, min=0.0), 2))


        return loss_contrastive

# %%
train_dataloader = DataLoader(siamese_dataset,
                        shuffle=True,
                        num_workers=8,
                        batch_size=Config.train_batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
net = SiameseNetwork().cuda()
criterion = ContrastiveLoss()
optimizer = optim.Adam(net.parameters(),lr = 0.0005 )

# %%
counter = []
loss_history = [] 
iteration_number= 0

# %%
for epoch in range(0,Config.train_number_epochs):
    for i, data in enumerate(train_dataloader,0):
        img0, img1, label = data
        img0, img1, label = img0.cuda(), img1.cuda() , label.cuda()
        optimizer.zero_grad()
        output1,output2 = net(img0,img1)
        loss_contrastive = criterion(output1,output2,label)
        loss_contrastive.backward()
        optimizer.step()
        if i %10 == 0 :
            print("Epoch number {}\n Current loss {}\n".format(epoch,loss_contrastive.item()))
            iteration_number +=10
            counter.append(iteration_number)
            loss_history.append(loss_contrastive.item())
show_plot(counter,loss_history)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Epoch number 0
#  Current loss 1.7026152610778809
#
# Epoch number 1
#  Current loss 0.6168121695518494
#
# Epoch number 2
#  Current loss 1.143250584602356
#
# Epoch number 3
#  Current loss 4.513291358947754
#
# Epoch number 4
#  Current loss 0.1944991797208786
#
# Epoch number 5
#  Current loss 0.49612975120544434
#
# Epoch number 6
#  Current loss 1.1506980657577515
#
# Epoch number 7
#  Current loss 0.27642568945884705
#
# Epoch number 8
#  Current loss 2.560542345046997
#
# Epoch number 9
#  Current loss 1.1206308603286743
#
# Epoch number 10
#  Current loss 0.6766167879104614
#
# Epoch number 11
#  Current loss 0.44211578369140625
#
# Epoch number 12
#  Current loss 1.8854119777679443
#
# Epoch number 13
#  Current loss 0.4492793679237366
#
# Epoch number 14
#  Current loss 1.660684585571289
#
# Epoch number 15
#  Current loss 1.4377412796020508
#
# Epoch number 16
#  Current loss 0.5335676074028015
#
# Epoch number 17
#  Current loss 0.06640270352363586
#
# Epoch number 18
#  Current loss 0.10611994564533234
#
# Epoch number 19
#  Current loss 0.5757957696914673
#
# Epoch number 20
#  Current loss 3.324216365814209
#
# Epoch number 21
#  Current loss 4.295924186706543
#
# Epoch number 22
#  Current loss 0.1990201473236084
#
# Epoch number 23
#  Current loss 18.58448028564453
#
# Epoch number 24
#  Current loss 0.2841382920742035
#
# Epoch number 25
#  Current loss 1.095564603805542
#
# Epoch number 26
#  Current loss 13.085500717163086
#
# Epoch number 27
#  Current loss 1.3886427879333496
#
# Epoch number 28
#  Current loss 0.292527437210083
#
# Epoch number 29
#  Current loss 0.46590369939804077
#
# Epoch number 30
#  Current loss 0.14936961233615875
#
# Epoch number 31
#  Current loss 1.2545301914215088
#
# Epoch number 32
#  Current loss 1.0342271327972412
#
# Epoch number 33
#  Current loss 0.10749833285808563
#
# Epoch number 34
#  Current loss 0.05362411215901375
#
# Epoch number 35
#  Current loss 2.980872392654419
#
# Epoch number 36
#  Current loss 1.1112146377563477
#
# Epoch number 37
#  Current loss 2.1212117671966553
#
# Epoch number 38
#  Current loss 0.10259407013654709
#
# Epoch number 39
#  Current loss 0.9489197134971619
#
# Epoch number 40
#  Current loss 0.6338639259338379
#
# Epoch number 41
#  Current loss 1.0666065216064453
#
# Epoch number 42
#  Current loss 0.3118438422679901
#
# Epoch number 43
#  Current loss 0.19470950961112976
#
# Epoch number 44
#  Current loss 4.451141834259033
#
# Epoch number 45
#  Current loss 0.15559843182563782
#
# Epoch number 46
#  Current loss 0.5302704572677612
#
# Epoch number 47
#  Current loss 0.0493822880089283
#
# Epoch number 48
#  Current loss 0.5465996265411377
#
# Epoch number 49
#  Current loss 0.9798117280006409
#
# Epoch number 50
#  Current loss 8.678178787231445
#
# Epoch number 51
#  Current loss 0.015578662045300007
#
# Epoch number 52
#  Current loss 0.06607314944267273
#
# Epoch number 53
#  Current loss 0.021854504942893982
#
# Epoch number 54
#  Current loss 10.47390079498291
#
# Epoch number 55
#  Current loss 0.042230796068906784
#
# Epoch number 56
#  Current loss 0.07732334733009338
#
# Epoch number 57
#  Current loss 0.07712377607822418
#
# Epoch number 58
#  Current loss 0.0546494796872139
#
# Epoch number 59
#  Current loss 0.030635429546236992
#
# Epoch number 60
#  Current loss 2.560753583908081
#
# Epoch number 61
#  Current loss 0.6085903644561768
#
# Epoch number 62
#  Current loss 1.6255043745040894
#
# Epoch number 63
#  Current loss 0.4895731508731842
#
# Epoch number 64
#  Current loss 6.582213878631592
#
# Epoch number 65
#  Current loss 0.11848433315753937
#
# Epoch number 66
#  Current loss 58.835235595703125
#
# Epoch number 67
#  Current loss 0.4802238941192627
#
# Epoch number 68
#  Current loss 0.5346658229827881
#
# Epoch number 69
#  Current loss 0.6563962697982788
#
# Epoch number 70
#  Current loss 0.5286481380462646
#
# Epoch number 71
#  Current loss 0.3855130076408386
#
# Epoch number 72
#  Current loss 6.549584865570068
#
# Epoch number 73
#  Current loss 0.2081560492515564
#
# Epoch number 74
#  Current loss 0.6616863012313843
#
# Epoch number 75
#  Current loss 0.08161019533872604
#
# Epoch number 76
#  Current loss 0.00668042479082942
#
# Epoch number 77
#  Current loss 0.394491970539093
#
# Epoch number 78
#  Current loss 0.1119539737701416
#
# Epoch number 79
#  Current loss 0.12305080145597458
#
# Epoch number 80
#  Current loss 0.1250971257686615
#
# Epoch number 81
#  Current loss 0.7691542506217957
#
# Epoch number 82
#  Current loss 0.01659034937620163
#
# Epoch number 83
#  Current loss 0.5378539562225342
#
# Epoch number 84
#  Current loss 0.06423407047986984
#
# Epoch number 85
#  Current loss 2.8301329612731934
#
# Epoch number 86
#  Current loss 0.2646051347255707
#
# Epoch number 87
#  Current loss 0.290967732667923
#
# Epoch number 88
#  Current loss 0.49040281772613525
#
# Epoch number 89
#  Current loss 0.437548965215683
#
# Epoch number 90
#  Current loss 0.44347548484802246
#
# Epoch number 91
#  Current loss 0.9460982084274292
#
# Epoch number 92
#  Current loss 0.020460911095142365
#
# Epoch number 93
#  Current loss 0.9186359643936157
#
# Epoch number 94
#  Current loss 0.5330345630645752
#
# Epoch number 95
#  Current loss 0.21607770025730133
#
# Epoch number 96
#  Current loss 0.005527824629098177
#
# Epoch number 97
#  Current loss 0.5121608972549438
#
# Epoch number 98
#  Current loss 31.399250030517578
#
# Epoch number 99
#  Current loss 0.39888355135917664

# %%
class GetTwoData(Dataset):
    
    def __init__(self, find_img_tuple, comapare_img_tuple, imageFolderDataset,transform=None,should_invert=True):
        self.imageFolderDataset = imageFolderDataset    
        self.transform = transform
        self.should_invert = should_invert
        self.find_img_tuple = find_img_tuple
        self.comapare_img_tuple = comapare_img_tuple
        
    def __getitem__(self,index):
        img0_tuple = find_img_tuple
        img1_tuple = compare_img_tuple

        img0 = Image.open(img0_tuple[0])
        img1 = Image.open(img1_tuple[0])
        img0 = img0.convert("L")
        img1 = img1.convert("L")
        
        if self.should_invert:
            img0 = PIL.ImageOps.invert(img0)
            img1 = PIL.ImageOps.invert(img1)

        if self.transform is not None:
            img0 = self.transform(img0)
            img1 = self.transform(img1)
        
        return img0, img1 , torch.from_numpy(np.array([int(img1_tuple[1]!=img0_tuple[1])],dtype=np.float32))
    
    def __len__(self):
        return len(self.imageFolderDataset.imgs)

# %%
result_dict = dict()

find_src = "/content/images1/Training/s15/다운로드 (32).jpg"

# 테스트 이미지 파일에서 이미지 가져오기
find_train = dset.ImageFolder(root=Config.training_dir)
folder_dataset_test = dset.ImageFolder(root=Config.testing_dir)

for value in find_train.imgs:
    if (value[0] == find_src):
        find_img_tuple = value
        break

for i in range(1,len(folder_dataset_test)+1):
    compare_src = "/content/images1/Testing/s" + str((i)) + "/" + str((i)) + ".jpg"
    compare_test = dset.ImageFolder(root=Config.testing_dir)
    for value in compare_test.imgs:
        if (value[0] == compare_src):
            compare_img_tuple = value
            break

    siamese_dataset = GetTwoData(find_img_tuple, compare_img_tuple, imageFolderDataset=folder_dataset_test,
                             transform=transforms.Compose([transforms.Resize((100,100)),
                                                           transforms.ToTensor()
                                                           ])
                             ,should_invert=False)

    test_dataloader = DataLoader(siamese_dataset,num_workers=0,batch_size=1,shuffle=True)
    dataiter = iter(test_dataloader)
    x0,_,_ = next(dataiter)
    
    _,x1,label2 = next(dataiter)
    concatenated = torch.cat((x0,x1),0)

    output1,output2 = net(Variable(x0).cuda(),Variable(x1).cuda())
    euclidean_distance = F.pairwise_distance(output1, output2)
    imshow(torchvision.utils.make_grid(concatenated),'Dissimilarity: {:.2f}'.format(euclidean_distance.item()))
    result_dict[compare_src] = euclidean_distance.item()

#결과 값
print(type(result_dict))
print(result_dict)

#정렬
sorted_result = sorted(result_dict.items(), key = lambda item: item[1])

#정렬을 하면 list로 바뀌므로 다시 dictionary로 변환
dict_ = dict(sorted_result)

#dictionary를 json으로 변환
import json
json_result = json.dumps(dict_)
print(type(json_result))
print(json_result)
# Out:
# <class 'dict'>
# {'/content/images1/Testing/s1/1.jpg': 1.554185390472412, '/content/images1/Testing/s2/2.jpg': 1.5594984292984009, '/content/images1/Testing/s3/3.jpg': 1.5820989608764648, '/content/images1/Testing/s4/4.jpg': 1.5904896259307861, '/content/images1/Testing/s5/5.jpg': 1.6524677276611328, '/content/images1/Testing/s6/6.jpg': 1.5594984292984009, '/content/images1/Testing/s7/7.jpg': 1.5192208290100098, '/content/images1/Testing/s8/8.jpg': 1.6853646039962769, '/content/images1/Testing/s9/9.jpg': 1.5953054428100586, '/content/images1/Testing/s10/10.jpg': 3.3929097652435303, '/content/images1/Testing/s11/11.jpg': 2.047280788421631, '/content/images1/Testing/s12/12.jpg': 1.524766206741333, '/content/images1/Testing/s13/13.jpg': 1.8766543865203857, '/content/images1/Testing/s14/14.jpg': 1.5594984292984009, '/content/images1/Testing/s15/15.jpg': 2.6217541694641113, '/content/images1/Testing/s16/16.jpg': 1.5785768032073975, '/content/images1/Testing/s17/17.jpg': 1.3931492567062378, '/content/images1/Testing/s18/18.jpg': 2.0465664863586426, '/content/images1/Testing/s19/19.jpg': 1.7771766185760498}
# <class 'list'>
